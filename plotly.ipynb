# %% [markdown]
# Q.1  Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
# scatter plot for age and fare columns in the titanic dataset.

# %%
ANS-: o load the Titanic dataset using the load_dataset function of seaborn and plot a scatter plot for age and fare columns, you can follow the steps below:

Import the necessary libraries:
python
Download
Copy code
import seaborn as sns
import plotly.express as px
Load the Titanic dataset using the load_dataset function:
python
Download
Copy code
titanic_data = sns.load_dataset('titanic')
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = titanic_data[['age', 'fare']]
Use Plotly Express to create the scatter plot:
python
Download
Copy code
fig = px.scatter(data, x='age', y='fare')
fig.show()
This will create a scatter plot with age on the x-axis and fare on the y-axis. You can customize the plot further by adding labels, title, or changing the color scheme as needed.
# Out:
#   Cell In[1], line 1
#     ANS-: o load the Titanic dataset using the load_dataset function of seaborn and plot a scatter plot for age and fare columns, you can follow the steps below:
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q.2 Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
python
Download
Copy code
import plotly.express as px
Load the tips dataset using the load_dataset function:
python
Download
Copy code
tips_data = px.data.tips()
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = tips_data[['total_bill', 'day', 'time']]
Use Plotly Express to create the box plot:
python
Download
Copy code
fig = px.box(data, x='day', y='total_bill', color='time', title='Box plot of total bill by day and time')
fig.show()
This will create a box plot with day on the x-axis and total bill on the y-axis. The plot will be colored based on the time of day. You can customize the plot further by adding labels, title, or changing the color scheme as needed.

Note: The tips dataset is already included in the Plotly library, so you don't need to load it using seaborn's load_dataset function. Instead, you can directly load it using px.data.tips().

# %% [markdown]
# Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
# the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
# column with the color parameter.

# %%
ANS -;  

To plot a histogram for x= "sex" and y="total_bill" column in the tips dataset using Plotly, you can follow the steps below:

Import the necessary libraries:
python
Download
Copy code
import plotly.express as px
Load the tips dataset using the load_dataset function:
python
Download
Copy code
tips_data = px.data.tips()
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = tips_data[['sex', 'total_bill', 'smoker', 'day']]
Use Plotly Express to create the histogram:
python
Download
Copy code
fig = px.histogram(data, x='sex', y='total_bill', color='day', pattern_shape='smoker', barmode='group')
fig.show()
This will create a histogram with sex on the x-axis and total bill on the y-axis. The plot will be colored based on the day column and use different patterns for the smoker column. The barmode parameter is set to 'group' to stack the bars for each day.

Note: The pattern_shape parameter is only available in the development version of Plotly Express. If you are using the stable version, you can use the facet_row parameter instead to create separate plots for each smoker category.

Here's an example:

Import the necessary libraries:
python
Download
Copy code
import plotly.express as px
Load the tips dataset using the load_dataset function:
python
Download
Copy code
tips_data = px.data.tips()
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = tips_data[['sex', 'total_bill', 'smoker', 'day']]
Use Plotly Express to create the histogram:
python
Download
Copy code
fig = px.histogram(data, x='sex', y='total_bill', color='day', facet_row='smoker', barmode='group')
fig.show()
This will create separate plots for each smoker category, with sex on the x-axis and total bill on the y-axis. The plot will be colored based on the day column. The barmode parameter is set to 'group' to stack the bars for each day.

# %% [markdown]
# Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
# the color parameter.

# %%
ANS-:    Sources: plotly.com (1) plotly.com (2) analyticsvidhya.com (3) yan-holtz.com (4)

To plot a scatter matrix plot using the iris dataset in the Plotly library with the "species" column for the color parameter, you can use the plot_ly function from the plotly library and the scattermatrix function from the ggpLOT library. Here's an example:

Import the necessary libraries:
python
Download
Copy code
import plotly.graph_objects as go
import ggpLOT as gg
Load the iris dataset using the read_csv function:
python
Download
Copy code
iris_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris.csv')
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = iris_data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']]
Use gg to create the scatter matrix plot:
python
Download
Copy code
p = gg.ggplot(data, gg.aes(x='sepal_length', y='sepal_width')) + \
    gg.geom_point(gg.aes(color='species')) + \
    gg.geom_point(gg.aes(x='sepal_length', y='petal_length')) + \
    gg.geom_point(gg.aes(x='sepal_length', y='petal_width')) + \
    gg.geom_point(gg.aes(x='sepal_width', y='petal_length')) + \
    gg.geom_point(gg.aes(x='sepal_width', y='petal_width')) + \
    gg.geom_point(gg.aes(x='petal_length', y='petal_width'))
Use plotly to create the interactive plot:
python
Download
Copy code
fig = gg.ggplotly(p)
fig.show()
This will create a scatter matrix plot with sepal length on the x-axis and sepal width on the y-axis, with points colored by species. The plot will also include scatter plots for the other variables.

Note: The scattermatrix function from the ggpLOT library is not available in the latest version of the library. The example above uses individual scatter plots for each combination of variables. If you have an older version of ggpLOT that includes the scattermatrix function, you can use it instead of the individual scatter plots.

Here's an example using scattermatrix:

Import the necessary libraries:
python
Download
Copy code
import plotly.graph_objects as go
import ggpLOT as gg
Load the iris dataset using the read_csv function:
python
Download
Copy code
iris_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris.csv')
Prepare the data for plotting by selecting the relevant columns:
python
Download
Copy code
data = iris_data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']]
Use gg to create the scatter matrix plot:
python
Download
Copy code
p = gg.ggplot(data, gg.aes(x='species')) + \
    gg.geom_scattermatrix(gg.aes(x='sepal_length', y='sepal_width'), color='species') + \
    gg.geom_scattermatrix(gg.aes(x='sepal_length', y='petal_length'), color='species') + \
    gg.geom_scattermatrix(gg.aes(x='sepal_length', y='petal_width'), color='species') + \
    gg.geom_scattermatrix(gg.aes(x='sepal_width', y='petal_length'), color='species') + \
    gg.geom_scattermatrix(gg.aes(x='sepal_width', y='petal_width'), color='species') + \
    gg.geom_scattermatrix(

# %% [markdown]
# Q5. What is Distplot? Using Plotly express, plot a distplot.

# %%
ANS-:    Distplot is a figure factory in Plotly that displays a combination of statistical representations of numerical data, such as histogram, kernel density estimation or normal curve, and rug plot. It can be created using the plotly.figure_factory.create_distplot() function.

Here's an example of how to create a distplot using Plotly Express:

First, let's import the necessary libraries:

python
Download
Copy code
import numpy as np
import plotly.express as px
Next, let's create some random data to plot:

python
Download
Copy code
x = np.random.randn(1000)
Finally, let's create the distplot using Plotly Express:

python
Download
Copy code
fig = px.histogram(x=x, nbins=20, marginal="rug")
fig.show()
This will create a histogram with 20 bins and a rug plot on the bottom. The marginal parameter specifies that the rug plot should be displayed on the marginal axis.

Note that Plotly Express does not have a built-in function for creating distplots, so we need to use the px.histogram() function instead. However, this function allows us to create a similar plot with similar statistical representations.
